# %%
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('SeoulBikeDataNew.csv')

# %%
data
# Out:
#             Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0     01/12/2017                254     0             -5.2           37
# 1     01/12/2017                204     1             -5.5           38
# 2     01/12/2017                173     2             -6.0           39
# 3     01/12/2017                107     3             -6.2           40
# 4     01/12/2017                 78     4             -6.0           36
# ...          ...                ...   ...              ...          ...
# 8755  30/11/2018               1003    19              4.2           34
# 8756  30/11/2018                764    20              3.4           37
# 8757  30/11/2018                694    21              2.6           39
# 8758  30/11/2018                712    22              2.1           41
# 8759  30/11/2018                584    23              1.9           43
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# ...

# %%
day1 = data[0:24]
print(day1)
# Out:
#           Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0   01/12/2017                254     0             -5.2           37
# 1   01/12/2017                204     1             -5.5           38
# 2   01/12/2017                173     2             -6.0           39
# 3   01/12/2017                107     3             -6.2           40
# 4   01/12/2017                 78     4             -6.0           36
# 5   01/12/2017                100     5             -6.4           37
# 6   01/12/2017                181     6             -6.6           35
# 7   01/12/2017                460     7             -7.4           38
# 8   01/12/2017                930     8             -7.6           37
# 9   01/12/2017                490     9             -6.5           27
# 10  01/12/2017                339    10             -3.5           24
# 11  01/12/2017                360    11             -0.5           21
# ...

# %%
bikecount = data['Rented Bike Count']
print(day2)
# Out:
# 24    328
# 25    308
# 26    262
# 27    167
# 28     89
# 29     79
# 30     70
# 31    146
# 32    219
# 33    328
# 34    334
# 35    388
# 36    479
# 37    606
# 38    611
# 39    589
# 40    618
# 41    572
# 42    489
# 43    385
# 44    359
# 45    377
# 46    354
# 47    366
# Name: Rented Bike Count, dtype: int64

# %%
day1count = bikecount[0:23]
print(bikecount[0:23])
sum(day1count)
# Out:
# 0     254
# 1     204
# 2     173
# 3     107
# 4      78
# 5     100
# 6     181
# 7     460
# 8     930
# 9     490
# 10    339
# 11    360
# 12    449
# 13    451
# 14    447
# 15    463
# 16    484
# 17    555
# 18    862
# 19    600
# 20    426
# 21    405
# 22    398
# Name: Rented Bike Count, dtype: int64
# 9216

# %%
#generate one week of data
day1 = bikecount[0:23]
day2 = bikecount[24:48]
day3 = bikecount[49:72]
day4 = bikecount[73:96]
day5 = bikecount[97:120]
day6 = bikecount[121:144]
day7 = bikecount[145:168]

# %%
#sum rental totals
sum1 = sum(day1)
sum2 = sum(day2)
sum3 = sum(day3)
sum4 = sum(day4)
sum5 = sum(day5)
sum6 = sum(day6)
sum7 = sum(day7)

# %%
x = [1,2,3,4,5,6,7]
y = [sum1,sum2,sum3,sum4,sum5,sum6,sum7]

# %%
plt.plot(x,y)
plt.scatter(x,y)
plt.xlabel('Day Count')
plt.ylabel('Number of Bike Rentals')
# Out:
# Text(0, 0.5, 'Number of Bike Rentals')

# %%
import sklearn.linear_model
model = sklearn.linear_model.LinearRegression()

# %%
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(
    x, y)
x_train = np.array(x_train)
x_test = np.array(x_test)

# %%
x_train = np.reshape(x_train, 5)
x_test = np.reshape(x_test, 2)

model.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_60/2574650060.py in <module>
#       2 x_test = np.reshape(x_test, 2)
#       3
# ----> 4 model.fit(x,y)
#
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     516         accept_sparse = False if self.positive else ['csr', 'csc', 'coo']
#     517
# --> 518         X, y = self._validate_data(X, y, accept_sparse=accept_sparse,
#     519                                    y_numeric=True, multi_output=True)
#     520
#
# /opt/conda/lib/python3.9/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# ...

# %%
x_test = [[25000]]
model.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# /tmp/ipykernel_60/870443226.py in <module>
#       1 x_test = [[25000]]
# ----> 2 model.predict(x_test)
#
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     236             Returns predicted values.
#     237         """
# --> 238         return self._decision_function(X)
#     239
#     240     _preprocess_data = staticmethod(_preprocess_data)
#
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     216
#     217     def _decision_function(self, X):
# --> 218         check_is_fitted(self)
#     219
#     220         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
# ...
